# %%
from matplotlib import colors
import folium
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
# %matplotlib inline


dataset_path = './Data/Map-Crime_Incidents-Previous_Three_Months.csv'
SF = pd.read_csv(dataset_path)

pd.set_option('display.max_rows', 10)
print(SF.columns)
print(len(SF))

SF['Month'] = SF['Date'].apply(lambda row: int(row[0:2]))
SF['Day'] = SF['Date'].apply(lambda row: int(row[3:5]))
head - n 5 ./Data/Map-Crime_Incidents-Previous_Three_Months.csv
print(SF['Month'][0:2])
print(SF['Day'][0:2])
print(type(SF['Month'][0]))

del SF['IncidntNum']
SF.drop('Location', axis=1, inplace=True)
print(SF.columns)

CountCategory = SF['Category'].value_counts(ascending=True)
print(CountCategory)

AugustCrimes = SF[SF['Month'] == 8]
print(AugustCrimes)

AugustCrimes = SF[SF['Month'] == 8]
AugustCrimesB = SF[SF['Category'] == 'BURGLARY']
print(len(AugustCrimes))
print(len(AugustCrimesB))

Crime0704 = SF.query('Month == 7 and Day == 4')
Crime0704

print(SF.columns)

districts = np.unique(SF['PdDistrict'])
print(list(colors.cnames.values())[0:len(districts)])

pd_districts = np.unique(SF['PdDistrict'])
pd_districts_levels = dict(zip(pd_districts, range(len(pd_districts))))
pd_districts_levels

SF['PdDistrictCode'] = SF['PdDistrict'].apply(
    lambda row: pd_districts_levels[row])

plt.scatter(SF['X'], SF['Y'], c=SF['PdDistrictCode'])
plt.show()

color_dict = dict(
    zip(districts, list(colors.cnames.values())[0:-1:len(districts)]))
color_dict

map_osm = folium.Map(location=[SF['Y'].mean(), SF['X'].mean()], zoom_start=12)
plotEvery = 50
obs = list(zip(SF['Y'], SF['X'], SF['PdDistrict']))


for el in obs[0:-1:plotEvery]:
  folium.CircleMarker(el[0:2], color=color_dict[el[2]],
                      fill_color=el[2], radius=10).add_to(map_osm)

map_osm
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_8bf2a6824ab25c7281ac1a6d50e5502f {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_8bf2a6824ab25c7281ac1a6d50e5502f&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_8bf2a6824ab25c7281ac1a6d50e5502f = L.map(
#                 &quot;map_8bf2a6824ab25c7281ac1a6d50e5502f&quot;,
#                 {
#                     center: [37.76854108075901, -122.42182192941803],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_7b9a225ccea993a71e8bde2e7f7e854f = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_8bf2a6824ab25c7281ac1a6d50e5502f);
#
#
#             var circle_marker_3e745ee18689adfb81d591ab4e470e7f = L.circleMarker(
#                 [37.7909741243888, -122.417392830334],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#8A2BE2&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;CENTRAL&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 10, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_8bf2a6824ab25c7281ac1a6d50e5502f);
#
#
#             var circle_marker_4e5e556457922a0a7e7f74c6547d4925 = L.circleMarker(
#                 [37.7503352730133, -122.415009359267],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#FF8C00&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;MISSION&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 10, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_8bf2a6824ab25c7281ac1a6d50e5502f);
#
#
#             var circle_marker_a72ba70bf1c76c8e828a768035501064 = L.circleMarker(
#                 [37.7845681170633, -122.431206932079],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#FF1493&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;NORTHERN&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 10, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_8bf2a6824ab25c7281ac1a6d50e5502f);
#
#
#             var circle_marker_a11a6f06dbdcaf9bba0b55c8619400c0 = L.circleMarker(
#                 [37.7873594949856, -122.408231026261],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#8A2BE2&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;CENTRAL&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 10, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_8bf2a6824ab25c7281ac1a6d50e5502f);
#
#
#             var circle_marker_38caaac9a5a71e30a9f019e3cb24c5f3 = L.circleMarker(
#                 [37.7359691377557, -122.421793189065],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#00FFFF&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;INGLESIDE&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 10, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_8bf2a6824ab25c7281ac1a6d50e5502f);
#
#
#             var circle_marker_fff36cdc7de15f0255c06483dab6f70b = L.circleMarker(
#                 [37.788837905642, -122.389432577161],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#FAFAD2&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;SOUTHERN&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 10, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_8b
